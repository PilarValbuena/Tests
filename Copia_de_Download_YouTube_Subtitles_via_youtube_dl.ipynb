# %% [markdown]
# <a href="https://colab.research.google.com/github/PilarValbuena/Coursera/blob/master/Copia_de_Download_YouTube_Subtitles_via_youtube_dl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to download YouTube Subtitles for Sentimental Analysis
#
# **The main steps in this notebook are:**
#
# * Download the subtitles file(s)
# * Convert to a text file
# * Clean the text and remove duplications
# * Export to a text file
#
#
# **Subtitle Settings available via youtube-dl:**
#
# * --write-sub (Write subtitle file)
# * --write-auto-sub (Write automatic subtitle file (YouTube only))
# * --all-subs (Download all the available subtitles of the video)
# * --list-subs (List all available subtitles for the video)
# * --sub-format (FORMAT Subtitle format, accepts formats preference, for example: "srt" or "ass/srt/best")
# * --sub-lang LANGS (Languages of the subtitles to download (optional) separated by commas, use IETF language tags like 'en,pt')

# %%
#See official github page for this module at https://github.com/ytdl-org/youtube-dl/
#Download module to your Colab
# !pip install youtube-dl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting youtube-dl
#   Downloading youtube_dl-2021.12.17-py2.py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 4.3 MB/s
# Installing collected packages: youtube-dl
# Successfully installed youtube-dl-2021.12.17

# %% [markdown]
# # Insert YouTube URL and Subtitles Settings

# %%
from __future__ import unicode_literals
import youtube_dl

ydl_opts = {
'writesubtitles': True,
'writeautomaticsub': True,
'subtitle': '--write-sub --all-subs',
'skip_download': True, 
}
url = input("Please add YouTube link here:")
with youtube_dl.YoutubeDL(ydl_opts) as ydl:
    ydl.download([url])
print("Download Successful!")
# Out:
# Please add YouTube link here:https://www.youtube.com/watch?v=eLavzXLatPY
# [youtube] eLavzXLatPY: Downloading webpage
# [info] Writing video subtitles to: RSCF Knowledge Exchange Webinar - Mobilizing Finance-eLavzXLatPY.en.vtt
# Download Successful!

# %% [markdown]
# This module is very good an responsive. For example, it identified that there was no official subtitles which is very common. Luckily we can extract YouTube's automated subtitles which isn't perfect but is close enough.
#
# Once the download is successful, open the folder icon on the right hand side, right click and "Copy Path".

# %% [markdown]
# # Convert Subtitles file to Text File

# %%
#Taken from https://shkspr.mobi/blog/2018/09/convert-webvtt-to-a-transcript-using-python/
#https://github.com/glut23/webvtt-py
# !pip install webvtt-py
import webvtt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting webvtt-py
#   Downloading webvtt_py-0.4.6-py3-none-any.whl (16 kB)
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from webvtt-py) (0.6.2)
# Installing collected packages: webvtt-py
# Successfully installed webvtt-py-0.4.6

# %%
#Copy the path of thwe downloaded subtitles file here
file = "/content/RSCF Knowledge Exchange Webinar - Mobilizing Finance-eLavzXLatPY.en.vtt"
#Read the webvtt Subtitles file
vtt = webvtt.read(file) 
counter = 0
for i in range(len(vtt)):
  if counter < 10:
    print(vtt[i].text)
    counter+=1
# Out:
#
# um  i'd like to start by thanking our  panelists for joining us today i'll  introduce them uh in a minute i'd like  to thank also uh germany's international  climate initiative and luxembourg's  international climate finance program  for funding the restoration seed capital  facility and the knowledge exchange  webinar series that brings us together  today  now  generally these sort of scene-setting  introductions start by explaining the  need for more investment in nature-based  solutions but i think that case has now  been made and we'd like to focus a bit  more on how to achieve that  it's clear  that the current pattern of land use has  contributed  to the global environmental crises we  face and the innovative solutions  particularly in land use that combine  commercial viability with positive  environmental and social impact will  need to scale rapidly if they are to  effectively start responding to these  same environmental crises and that scale  will largely need to come from the  private sector  which will in turn require private  finance to support both the innovative  and risky discovery stage at which these  innovative models are identified and  tried out and later the replication and  scaling up of models that have been  shown to be successful to provide just  an idea of the scale we're talking about  current levels of investment in nature  will need to incre
  sustainable land use and nature-based  solutions is high on the agenda we hear  about it every day  new commitments and pledges come in  every day from businesses donors  and financial institutions  and we see the carbon market especially  voluntary carbon market uh reviving  massively providing a new source of  funding for these kind of ventures  however  it seems that when we look out we see  there's still relatively few new  investment vehicles dedicated to these  strategies reaching implementation stage  and the sector as a whole is still far  from the scale that is needed  and so to better understand where the  bottlenecks  are to accelerating private investment  in nature-based solutions  and to identify where there might be  opportunities for better alignment  between fund managers and investors we  have with us today a great panel of   ...

# %% [markdown]
# # Remove duplicates from Subtitles
#
# Above you should see duplicates if you have downloaded the automated subtitles.
#
# The code below will remove duplicates but if there's no duplicates, it will just organise the text into one paragraph.

# %%
#I want to convert YouTube’s auto-generated subtitles into a plain transcript.
#https://stackoverflow.com/questions/51784232/how-do-i-convert-the-webvtt-format-to-plain-text

# import webvtt
# vtt = webvtt.read('subtitles.vtt')
transcript = ""

lines = []
for line in vtt:
    # Strip the newlines from the end of the text.
    # Split the string if it has a newline in the middle
    # Add the lines to an array
    lines.extend(line.text.strip().splitlines())

# Remove repeated lines
previous = None
for line in lines:
    if line == previous:
       continue
    transcript += " " + line
    previous = line

print(transcript)
# Out:
#  um  i'd like to start by thanking our  panelists for joining us today i'll  introduce them uh in a minute i'd like  to thank also uh germany's international  climate initiative and luxembourg's  international climate finance program  for funding the restoration seed capital  facility and the knowledge exchange  webinar series that brings us together  today  now  generally these sort of scene-setting  introductions start by explaining the  need for more investment in nature-based  solutions but i think that case has now  been made and we'd like to focus a bit  more on how to achieve that  it's clear  that the current pattern of land use has  contributed  to the global environmental crises we  face and the innovative solutions  particularly in land use that combine  commercial viability with positive  environmental and social impact will  need to scale rapidly if they are to  effectively start responding to these  same environmental crises and that scale  will largely need to come from the  private sector  which will in turn require private  finance to support both the innovative  and risky discovery stage at which these  innovative models are identified and  tried out and later the replication and  scaling up of models that have been  shown to be successful to provide just  an idea of the scale we're talking about  current levels of investment in nature  will need to increase threefold by the  end of this decade and reach 4 trillion  dollars by 2050 according to uneps state  of finance or nature report  now  for capital to be deployed effectively  there's a key role to be played by the  intermediaries that sit  between the sources of capital on the  one hand and the land use activities on  the ground and in particular in this  webinar we'd like to focus on the role  fund managers who carry out  important functions of aggregating  ventures scale to attract investment  they can spread risk across a portfolio  of investment bring professional  management to the assets and ventures  that they manage while still preserving  innovation and impact  and is with that in mind that the  restoration seed capital facility was  set up a year and a half ago to support  fund managers  to accelerate deployment of capital to  activities that support forest  in particular  the restoration seed capital facility  supports fund managers at two crucial  stages that represent bottlenecks and  challenges in their operations  first is in pipeline and project  development as fund managers they'll  often have to originate and develop  their investment opportunities from the  ground up in this stage and this  particular topic was addressed in our  first knowledge to exchange webinar last  year  the other form of support we provide is  for  fund development  and that's not so much for the design  phase of new investment vehicles in this  space but more the phase of securing the  necessary funding from investors to get  operations started and that's the topic  that interests us today  now it can seem um  surprising that this represents a model  next till today because when you look  out it seems that the topic of land  sustainable land use and nature-based  solutions is high on the agenda we hear  about it every day  new commitments and pledges come in  every day from businesses donors  and financial institutions  and we see the carbon market especially  voluntary carbon market uh reviving  massively providing a new source of  funding for these kind of ventures  however  it seems that when we look out we see  there's still relatively few new  investment vehicles dedicated to these  strategies reaching implementation stage  and the sector as a whole is still far  from the scale that is needed  and so to better understand where the  bottlenecks  are to accelerating private investment  in nature-based solutions  and to identify where there might be  opportunities for better alignment  between fund managers and investors we  have with us today a great panel of  ...

# %% [markdown]
# # Save to Text File

# %%
text_file = open("transcript.txt", "w")
n = text_file.write(transcript)
text_file.close()

# %% [markdown]
# ###Tags cloud

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.64.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk) (2022.6.2)

# %%
##tags words
import nltk
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# True

# %%
from nltk.tokenize import sent_tokenize
from nltk.corpus import gutenberg
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
sample = gutenberg.raw("/content/transcript.txt")
tokenized = sent_tokenize(sample)
for i in tokenized[:2]:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            print(tagged)
# Out:
# [('there', 'RB'), ('you', 'PRP'), ('go', 'VBP'), ('i', 'JJ'), ('think', 'VBP'), ('this', 'DT'), ('one', 'NN'), ("'s", 'POS'), ('yeah', 'NN'), ('okay', 'IN'), ('we', 'PRP'), ("'ll", 'MD'), ('get', 'VB'), ('started', 'VBN'), ('in', 'IN'), ('about', 'IN'), ('one', 'CD'), ('minute', 'NN'), ('so', 'RB'), ('if', 'IN'), ('you', 'PRP'), ('could', 'MD'), ('start', 'VB'), ('to', 'TO'), ('take', 'VB'), ('your', 'PRP$'), ('seats', 'NNS'), ('please', 'VBP'), ('hello', 'JJ'), ('wow', 'NN'), ('hello', 'NN'), ('hello', 'NN'), ('yeah', 'NN'), ('[', 'NNP'), ('Music', 'NNP'), (']', 'NNP'), ('ready', 'NN'), ('to', 'TO'), ('go', 'VB'), ('good', 'JJ'), ('morning', 'NN'), ('ladies', 'NNS'), ('and', 'CC'), ('gentlemen', 'NNS'), ('welcome', 'VBP'), ('to', 'TO'), ('the', 'DT'), ('sustainable', 'JJ'), ('investment', 'NN'), ('in', 'IN'), ('forests', 'NNS'), ('for', 'IN'), ('people', 'NNS'), ('profit', 'VBP'), ('nature', 'NN'), ('of', 'IN'), ('the', 'DT'), ('50s', 'CD'), ('world', 'NN'), ('forest', 'NN'), ('congress', 'NN'), ('my', 'PRP$'), ('name', 'NN'), ('is', 'VBZ'), ('natalia', 'JJ'), ('granato', 'NN'), ('i', 'NN'), ("'m", 'VBP'), ('a', 'DT'), ('forest', 'NN'), ('engineer', 'NN'), ('and', 'CC'), ('i', 'JJ'), ('serve', 'VBP'), ('as', 'IN'), ('the', 'DT'), ('manage', 'NN'), ('manager', 'NN'), ('of', 'IN'), ('sustainability', 'NN'), ('and', 'CC'), ('forest', 'JJS'), ('affairs', 'NNS'), ('at', 'IN'), ('the', 'DT'), ('brazilian', 'JJ'), ('tree', 'NN'), ('industry', 'NN'), ('the', 'DT'), ('association', 'NN'), ('that', 'WDT'), ('represents', 'VBZ'), ('planted', 'VBN'), ('forest-based', 'JJ'), ('industry', 'NN'), ('in', 'IN'), ('brazil', 'NN'), ('i', 'NN'), ('also', 'RB'), ('serve', 'VBP'), ('as', 'IN'), ('vice', 'NN'), ('president', 'NN'), ('of', 'IN'), ('forest', 'JJ'), ('women', 'NNS'), ("'s", 'POS'), ('network', 'NN'), ('an', 'DT'), ('ngo', 'NN'), ('created', 'VBD'), ('to', 'TO'), ('discuss', 'VB'), ('about', 'IN'), ('gender', 'NN'), ('equity', 'NN'), ('in', 'IN'), ('the', 'DT'), ('forest', 'JJS'), ('based', 'VBN'), ('industry', 'NN'), ('in', 'IN'), ('brazil', 'NN'), ('it', 'PRP'), ('is', 'VBZ'), ('a', 'DT'), ('pleasure', 'NN'), ('and', 'CC'), ('an', 'DT'), ('honor', 'NN'), ('to', 'TO'), ('be', 'VB'), ('the', 'DT'), ('master', 'NN'), ('of', 'IN'), ('ceremony', 'NN'), ('of', 'IN'), ('such', 'JJ'), ('important', 'JJ'), ('and', 'CC'), ('long', 'JJ'), ('event', 'NN'), ('today', 'NN'), ('so', 'IN'), ('thank', 'JJ'), ('you', 'PRP'), ('for', 'IN'), ('choosing', 'VBG'), ('our', 'PRP$'), ('event', 'NN'), ('among', 'IN'), ('so', 'RB'), ('many', 'JJ'), ('other', 'JJ'), ('relevance', 'NN'), ('in', 'IN'), ('this', 'DT'), ('congress', 'NN'), ('i', 'JJ'), ('wish', 'VBP'), ('we', 'PRP'), ('have', 'VBP'), ('a', 'DT'), ('very', 'RB'), ('rich', 'JJ'), ('conversation', 'NN'), ('that', 'WDT'), ('make', 'VBP'), ('us', 'PRP'), ('leave', 'VBP'), ('the', 'DT'), ('room', 'NN'), ('with', 'IN'), ('more', 'JJR'), ('enthusiasm', 'NN'), ('and', 'CC'), ('energy', 'NN'), ('to', 'TO'), ('go', 'VB'), ('home', 'NN'), ('thinking', 'VBG'), ('about', 'IN'), ('actions', 'NNS'), ('to', 'TO'), ('deliver', 'VB'), ('i', 'NN'), ('want', 'VBP'), ('to', 'TO'), ('share', 'NN'), ('with', 'IN'), ('you', 'PRP'), ('a', 'DT'), ('very', 'RB'), ('positive', 'JJ'), ('message', 'NN'), ('to', 'TO'), ('start', 'VB'), ('our', 'PRP$'), ('session', 'NN'), ('i', 'NN'), ('always', 'RB'), ('say', 'VBP'), ('that', 'IN'), ('it', 'PRP'), ('is', 'VBZ'), ('very', 'RB'), ('comfort', 'JJ'), ('working', 'VBG'), ('with', 'IN'), ('forest-based', 'JJ'), ('industry', 'NN'), ('i', 'NN'), ('strongly', 'RB'), ('believe', 'VB'), ('on', 'IN'), ('this', 'DT'), ('because', 'IN'), ('there', 'EX'), ('is', 'VBZ'), ('no', 'DT'), ('more', 'RBR'), ('sustainable', 'JJ'), ('sector', 'NN'), ('than', 'IN'), ('ours', 'JJ'), ('thanks', 'NNS'), ('we', 'PRP'), ('are', 'VBP'), ('the', 'DT'), ('ones', 'NNS'), ('who', 'WP'), ('will', 'MD'), ('have', 'VB'), ('solutions', 'NNS'), ('for', 'IN'), ('climate', 'NN'), ('change', 'NN'), ('for', 'IN'), ('biodiv ...

# %%
tokenized
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4983c008c0e1> in <module>()
# ----> 1 tokenized
#
# NameError: name 'tokenized' is not defined

# %%
# image configurations
background_color = "#111111"
height = 720
width = 1080

# %%
# Read a text file and calculate frequency of words in it
with open("/content/transcript.txt", "r") as f:
    words = f.read().split()

# %%
from nltk.corpus import stopwords

# %%
"""
Python script to generate word cloud image.
Author - Anurag Rana
Read more on - https://www.pythoncircle.com
"""

from wordcloud import WordCloud

# image configurations
background_color = "#eeeeee"
height = 500
width = 1800                                                                                              

with open("/content/stopwords.txt", "r") as f:
    stop_words = f.read().split()

# Read a text file and calculate frequency of words in it
with open("/content/transcript.txt", "r") as f:
    words = f.read().split()

data = dict()

for word in words:
    word = word.lower()
    if word in stop_words:
        continue

    data[word] = data.get(word, 0) + 1

word_cloud = WordCloud(
    background_color=background_color,
    width=width,
    height=height
)

word_cloud.generate_from_frequencies(data)
word_cloud.to_file('image.png')
